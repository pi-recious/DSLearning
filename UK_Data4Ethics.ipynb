# %% [markdown]
# <a href="https://colab.research.google.com/github/pi-recious/DSLearning/blob/master/UK_Data4Ethics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
import io
import pandas as pd

df = pd.read_csv("EthnictyDataset.csv")
df #mean display the whole graph
# Out:
#                                      Ethnic Group  ...  Female death occurrence COVID-19 0-65
# 0                                           White  ...                               0.866726
# 1   English/Welsh/Scottish/Northern Irish/British  ...                                    NaN
# 2                                           Irish  ...                                    NaN
# 3                        Gypsy or Irish Traveller  ...                                    NaN
# 4                                     Other White  ...                                    NaN
# 5                                           Mixed  ...                               0.005516
# 6                       White and Black Caribbean  ...                                    NaN
# 7                         White and Black African  ...                                    NaN
# 8                                 White and Asian  ...                                    NaN
# 9                                     Other Mixed  ...                                    NaN
# 10                           Asian /Asian British  ...                                    NaN
# 11                                         Indian  ...                               0.035084
# 12                                      Pakistani  ...                               0.020741
# 13                                    Bangladeshi  ...                               0.020741
# 14                                        Chinese  ...                               0.003310
# 15                                    Other Asian  ...                                    NaN
# 16          Black/African/Caribbean/Black British  ...                               0.051412
# 17                                        African  ...                                    NaN
# 18                                      Caribbean  ...                                    NaN
# 19                                    Other Black  ...                                    NaN
# 20                             Other ethnic group  ...                               0.017211
# 21                                           Arab  ...                                    NaN
# 22                             Other Ethnic Group  ...                                    NaN
# 23                                          Total  ...                                    NaN
# 24                                            NaN  ...                                    NaN
# 25                                            NaN  ...                                    NaN
# 26                                            NaN  ...                                    NaN
# 27                                            NaN  ...                                    NaN
# 28                                            NaN  ...                                    NaN
# 29                                            NaN  ...                                    NaN
# 30                                            NaN  ...                                    NaN
# 31                                            NaN  ...                                    NaN
# 32                                            NaN  ...                                    NaN
# 33                                            NaN  ...                                    NaN
# 34                                            NaN  ...                                    NaN
# 35                                            NaN  ...                                    NaN
# 36                                            NaN  ...                                    NaN
# 37                                            NaN  ...                                    NaN
# 38                                            NaN  ...                                    NaN
# 39                                            NaN  ...                                    NaN
# 40                                            NaN  ...                                    NaN
# 41                                            NaN  ...                                    NaN
# 42                                            NaN  ...                                    NaN
# 43                                            NaN  ...                                    NaN
# 44                                            NaN  ...                                    NaN
#
# [45 rows x 12 columns]

# %%
df =df.dropna(axis=0, how='all')
df
# Out:
#                                      Ethnic Group  ...  Female death occurrence COVID-19 0-65
# 0                                           White  ...                               0.866726
# 1   English/Welsh/Scottish/Northern Irish/British  ...                                    NaN
# 2                                           Irish  ...                                    NaN
# 3                        Gypsy or Irish Traveller  ...                                    NaN
# 4                                     Other White  ...                                    NaN
# 5                                           Mixed  ...                               0.005516
# 6                       White and Black Caribbean  ...                                    NaN
# 7                         White and Black African  ...                                    NaN
# 8                                 White and Asian  ...                                    NaN
# 9                                     Other Mixed  ...                                    NaN
# 10                           Asian /Asian British  ...                                    NaN
# 11                                         Indian  ...                               0.035084
# 12                                      Pakistani  ...                               0.020741
# 13                                    Bangladeshi  ...                               0.020741
# 14                                        Chinese  ...                               0.003310
# 15                                    Other Asian  ...                                    NaN
# 16          Black/African/Caribbean/Black British  ...                               0.051412
# 17                                        African  ...                                    NaN
# 18                                      Caribbean  ...                                    NaN
# 19                                    Other Black  ...                                    NaN
# 20                             Other ethnic group  ...                               0.017211
# 21                                           Arab  ...                                    NaN
# 22                             Other Ethnic Group  ...                                    NaN
# 23                                          Total  ...                                    NaN
#
# [24 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 0 to 23
# Data columns (total 12 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Ethnic Group                                                24 non-null     object
#  1   COVID-19 deaths                                             24 non-null     float64
#  2   Percentage of COVID-19 deaths                               24 non-null     float64
#  3   Weighted Population in the UK                               24 non-null     float64
#  4   Main language is English/Welsh                              18 non-null     float64
#  5   Other main language: could speak English very well or well  18 non-null     float64
#  6   Other main language: could not speak English well           18 non-null     float64
#  7   Other main language: could not speak English                18 non-null     float64
#  8   Males death by COVID-19 ages: 0-64                          8 non-null      float64
#  9   Males death by COV19 ages:0 -64                             8 non-null      float64
#  10  Female death occurrence COVID-19 65+                        8 non-null      float64
#  11  Female death occurrence COVID-19 0-65                       8 non-null      float64
# dtypes: float64(11), object(1)
# memory usage: 2.4+ KB

# %%
df.columns
# Out:
# Index(['Ethnic Group', 'COVID-19 deaths', 'Percentage of COVID-19 deaths',
#        'Weighted Population in the UK', 'Main language is English/Welsh',
#        'Other main language: could speak English very well or well',
#        'Other main language: could not speak English well',
#        'Other main language: could not speak English',
#        'Males death by COVID-19 ages: 0-64', 'Males death by COV19 ages:0 -64',
#        'Female death occurrence COVID-19 65+',
#        'Female death occurrence COVID-19 0-65'],
#       dtype='object')

# %%
df.describe()
# Out:
#        COVID-19 deaths  ...  Female death occurrence COVID-19 0-65
# count        24.000000  ...                               8.000000
# mean       4744.500000  ...                               0.127593
# std       11567.119746  ...                               0.299057
# min          16.000000  ...                               0.003310
# 25%         112.250000  ...                               0.014287
# 50%         343.000000  ...                               0.020741
# 75%         936.000000  ...                               0.039166
# max       37956.000000  ...                               0.866726
#
# [8 rows x 11 columns]

# %%
#Importing libraries for data visualization

dffloats = df.iloc[0:22].drop(['Ethnic Group'], axis=1) #new dataframe created
#dffloats['Ethnic Group'] = pd.CategoricalIndex(df['Ethnic Group']).codes

cols = dffloats.columns
dffloats[cols] = dffloats[cols].apply(pd.to_numeric, errors='coerce')

import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
dffloats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 0 to 21
# Data columns (total 11 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   COVID-19 deaths                                             22 non-null     float64
#  1   Percentage of COVID-19 deaths                               22 non-null     float64
#  2   Weighted Population in the UK                               22 non-null     float64
#  3   Main language is English/Welsh                              17 non-null     float64
#  4   Other main language: could speak English very well or well  17 non-null     float64
#  5   Other main language: could not speak English well           17 non-null     float64
#  6   Other main language: could not speak English                17 non-null     float64
#  7   Males death by COVID-19 ages: 0-64                          8 non-null      float64
#  8   Males death by COV19 ages:0 -64                             8 non-null      float64
#  9   Female death occurrence COVID-19 65+                        8 non-null      float64
#  10  Female death occurrence COVID-19 0-65                       8 non-null      float64
# dtypes: float64(11)
# memory usage: 2.1 KB

# %%
dffloats.head()
# Out:
#    COVID-19 deaths  ...  Female death occurrence COVID-19 0-65
# 0          33630.0  ...                               0.866726
# 1          32160.0  ...                                    NaN
# 2            666.0  ...                                    NaN
# 3             16.0  ...                                    NaN
# 4            788.0  ...                                    NaN
#
# [5 rows x 11 columns]

# %%
#Plotting a bunch of histograms
f, axes = plt.subplots(3, 4, figsize=(25, 10))#Setting a figure size
i = 0
j = 0
for column in dffloats.columns:
  if j <=3 :
    sns.distplot( dffloats[column], ax=axes[i, j], kde = False)
    j += 1
  else:
    i += 1
    j = 0
    sns.distplot( dffloats[column], ax=axes[i, j], kde = False) 
    j += 1
f.suptitle("X")
plt.show()

# %%
dframe=dffloats.drop(['COVID-19 deaths'], axis=1)
dframe.describe()
# Out:
#        Percentage of COVID-19 deaths  ...  Female death occurrence COVID-19 0-65
# count                      22.000000  ...                               8.000000
# mean                        9.077273  ...                               0.127593
# std                        25.159585  ...                               0.299057
# min                         0.000000  ...                               0.003310
# 25%                         0.225000  ...                               0.014287
# 50%                         0.900000  ...                               0.020741
# 75%                         2.325000  ...                               0.039166
# max                        88.600000  ...                               0.866726
#
# [8 rows x 10 columns]

# %%
#fig = plt.figure(figsize=(45,20), facecolor=None )
dframe.plot.bar(figsize=(35,15))
plt.axhline(0, color='k');
plt.rcParams["font.size"] = 20

# %%
dframe[['Percentage of COVID-19 deaths']].plot.bar(figsize=(35,10))
plt.xticks(range(len(df)), df['Ethnic Group'], rotation=90)
plt.rcParams["font.size"] = 20
plt.title('Proportion of COVID-19 Deaths by ethnicity')
# Out:
# Text(0.5, 1.0, 'Proportion of COVID-19 Deaths by ethnicity')

# %%
dffloats[['Main language is English/Welsh','Other main language: could speak English very well or well',
  'Other main language: could not speak English well',
  'Other main language: could not speak English']].plot.bar(figsize=(38,10))
plt.xticks(range(len(df)), df["Ethnic Group"])
plt.title('Level of English spoken by Ethnicity',fontdict={'fontsize': 35})
plt.xlabel('Ethnic group')
# Out:
# Text(0.5, 0, 'Ethnic group')

# %%
dffloats[['Percentage of COVID-19 deaths']].plot.line()

# %%
index = df['Ethnic Group']
dataplot = dframe.plot.barh()
#plot.tile('COVID-19 Death Rate features', fontdict=('fontname:' Tme))
#plt.xlabel(Ethnic Group)

# %%
dframe.plot.bar(x='Weighted Population in the UK', y='Percentage of COVID-19 deaths')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

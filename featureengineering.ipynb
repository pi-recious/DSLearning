# %% [markdown]
# <a href="https://colab.research.google.com/github/pi-recious/DSLearning/blob/master/featureengineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataethics4all
# ***Preprocessing***
#
# ![FE.jpeg](data:image/jpeg;base64,...)
#
# Feature Engineering

# %%
! python -m pip install featuretools[complete]

# %%
#This shows the current features and relationships of a dataset
import featuretools as ft
es = ft.demo.load_mock_customer(return_entityset=True)
es.plot()

# %%
feature_matrix, features_defs = ft.dfs(entityset=es, target_entity="customers")
feature_matrix.head(5)
